# %%
# %matplotlib inline

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='white')

from thinkstats2 import Pmf, Cdf

import thinkstats2
import thinkplot

# %%
data = pd.read_excel("/home/jobanner/The-Mother-Tongue-of-US-Communities/raw_data/DetailedLanguageSpoken_State_20062008.xls","AK",skiprows=[0,1,2]).dropna()

# %%
data.head
# Out:
# <bound method NDFrame.head of                                           Unnamed: 0 Number of speakers  \
# 0                     \n.Population 5 years and over             630423
# 1                         Spoke only English at home             533112
# 2        Spoke a language other than English at home              97311
# 3    \n\nSpoke a language other than English at home              97311
# 4                       \nSPANISH AND SPANISH CREOLE              22734
# 5                                          ..Spanish              22734
# 6                    \nOTHER INDO-EUROPEAN LANGUAGES              14309
# 7                                            .French               2039
# 8                                           ..French               2030
# 9                                           ..Patois                  9
# 10                                    .French Creole                167
# 11                                          .Italian                413
# ...
